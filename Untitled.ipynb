# %%
import pandas as pd
from pandas import DataFrame,Series

# %%
set=pd.read_csv('Salaries.csv',dtype='unicode')

# %%
set
# Out:
#             Id            EmployeeName  \
# 0            1          NATHANIEL FORD
# 1            2            GARY JIMENEZ
# 2            3          ALBERT PARDINI
# 3            4       CHRISTOPHER CHONG
# 4            5         PATRICK GARDNER
# 5            6          DAVID SULLIVAN
# 6            7               ALSON LEE
# 7            8           DAVID KUSHNER
# 8            9          MICHAEL MORRIS
# 9           10      JOANNE HAYES-WHITE
# 10          11           ARTHUR KENNEY
# 11          12        PATRICIA JACKSON
# 12          13       EDWARD HARRINGTON
# 13          14             JOHN MARTIN
# 14          15          DAVID FRANKLIN
# 15          16         RICHARD CORRIEA
# 16          17                AMY HART
# 17          18          SEBASTIAN WONG
# 18          19              MARTY ROSS
# 19          20           ELLEN MOFFATT
# 20          21              VENUS AZAR
# 21          22            JUDY MELINEK
# 22          23           GEORGE GARCIA
# ...

# %%
set.head()
# Out:
#   Id       EmployeeName                                        JobTitle  \
# 0  1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1  2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2  3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3  4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4  5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay OvertimePay   OtherPay Benefits   TotalPay TotalPayBenefits  \
# 0  167411.18         0.0  400184.25      NaN  567595.43        567595.43
# 1  155966.02   245131.88  137811.38      NaN  538909.28        538909.28
# 2  212739.13   106088.18    16452.6      NaN  335279.91        335279.91
# 3    77916.0    56120.71   198306.9      NaN  332343.61        332343.61
# 4   134401.6      9737.0  182234.59      NaN  326373.19        326373.19
#
#    Year Notes         Agency Status
# 0  2011   NaN  San Francisco    NaN
# ...

# %%
set['BasePay']
# Out:
# 0            167411.18
# 1            155966.02
# 2            212739.13
# 3              77916.0
# 4             134401.6
# 5             118602.0
# 6             92492.01
# 7            256576.96
# 8            176932.64
# 9             285262.0
# 10           194999.39
# 11             99722.0
# 12           294580.02
# 13           271329.03
# 14           174872.64
# 15           198778.01
# 16           268604.57
# 17           140546.87
# 18           168692.63
# 19           257510.59
# 20           257510.48
# 21           257510.44
# 22           140546.88
# 23           168692.63
# 24           140546.86
# 25           256470.41
# 26             92080.8
# 27           168692.59
# 28            261717.6
# 29            246225.6
#               ...
# 148624            0.00
# 148625            0.00
# 148626            0.00
# 148627            0.00
# 148628            0.00
# 148629            0.00
# 148630            0.00
# 148631            0.00
# 148632            0.00
# ...

# %%
set['BasePay'].max()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\bilal\Anaconda3\lib\site-packages\pandas\core\nanops.py in f(values, axis, skipna, **kwds)
#     118                 else:
# --> 119                     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     120             except Exception:
#
# C:\Users\bilal\Anaconda3\lib\site-packages\pandas\core\nanops.py in reduction(values, axis, skipna)
#     459         else:
# --> 460             result = getattr(values, meth)(axis)
#     461
#
# C:\Users\bilal\Anaconda3\lib\site-packages\numpy\core\_methods.py in _amax(a, axis, out, keepdims)
#      25 def _amax(a, axis=None, out=None, keepdims=False):
# ---> 26     return umr_maximum(a, axis, None, out, keepdims)
#      27
#
# TypeError: '>=' not supported between instances of 'str' and 'float'
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
set['JobTitle']
# Out:
# 0           GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1                          CAPTAIN III (POLICE DEPARTMENT)
# 2                          CAPTAIN III (POLICE DEPARTMENT)
# 3                     WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4             DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# 5                                ASSISTANT DEPUTY CHIEF II
# 6                       BATTALION CHIEF, (FIRE DEPARTMENT)
# 7                           DEPUTY DIRECTOR OF INVESTMENTS
# 8                       BATTALION CHIEF, (FIRE DEPARTMENT)
# 9                   CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)
# 10        ASSISTANT CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)
# 11                         CAPTAIN III (POLICE DEPARTMENT)
# 12                             EXECUTIVE CONTRACT EMPLOYEE
# 13                                       DEPARTMENT HEAD V
# 14                      BATTALION CHIEF, (FIRE DEPARTMENT)
# 15                      COMMANDER III, (POLICE DEPARTMENT)
# ...

# %%
set[set['EmployeeName']=='JOSEPH DRISCOLL']['JobTitle']
# Out:
# 24    CAPTAIN, FIRE SUPPRESSION
# Name: JobTitle, dtype: object

# %%
set[set['EmployeeName']=='JOSEPH DRISCOLL']
# Out:
#     Id     EmployeeName                   JobTitle    BasePay OvertimePay  \
# 24  25  JOSEPH DRISCOLL  CAPTAIN, FIRE SUPPRESSION  140546.86    97868.77
#
#     OtherPay Benefits   TotalPay TotalPayBenefits  Year Notes         Agency  \
# 24  31909.28      NaN  270324.91        270324.91  2011   NaN  San Francisco
#
#    Status
# 24    NaN

# %%
set[set['EmployeeName']=='JOSEPH DRISCOLL']['TotalPayBenefits']
# Out:
# 24    270324.91
# Name: TotalPayBenefits, dtype: object

# %%
set['TotalPayBenefits'].max()
# Out:
# '99999.81'

# %%
set[set['TotalPayBenefits']==set['TotalPayBenefits'].max()]['EmployeeName']
# Out:
# 92261    Mohammed H Khan
# Name: EmployeeName, dtype: object

# %%
set[set['EmployeeName']=='JOSEPH DRISCOLL']['BasePay']
# Out:
# 24    140546.86
# Name: BasePay, dtype: object

# %%
set.loc[set['TotalPayBenefits'].idxmax()]
# Out:
# Id                              92262
# EmployeeName          Mohammed H Khan
# JobTitle            Parts Storekeeper
# BasePay                       64827.0
# OvertimePay                   6379.37
# OtherPay                       1898.4
# Benefits                     26895.04
# TotalPay                     73104.77
# TotalPayBenefits             99999.81
# Year                             2013
# Notes                             NaN
# Agency                  San Francisco
# Status                            NaN
# Name: 92261, dtype: object

# %%
set.iloc[set['TotalPayBenefits'].argmin()]
# Out:
# Id                            110529
# EmployeeName        Timothy E Gibson
# JobTitle            Police Officer 3
# BasePay                          NaN
# OvertimePay                      0.0
# OtherPay                         0.0
# Benefits                       -2.73
# TotalPay                         0.0
# TotalPayBenefits               -2.73
# Year                            2013
# Notes                            NaN
# Agency                 San Francisco
# Status                           NaN
# Name: 110528, dtype: object

# %%
set[set['TotalPayBenefits']==set['TotalPayBenefits'].min()]['EmployeeName']
# Out:
# 110528    Timothy E Gibson
# Name: EmployeeName, dtype: object

# %%
set.groupby('Year').mean()
# Out:
# ---------------------------------------------------------------------------
# DataError                                 Traceback (most recent call last)
# <ipython-input-64-b2d8583c2894> in <module>()
# ----> 1 set.groupby('Year').mean()
#
# C:\Users\bilal\Anaconda3\lib\site-packages\pandas\core\groupby.py in mean(self, *args, **kwargs)
#    1035         nv.validate_groupby_func('mean', args, kwargs, ['numeric_only'])
#    1036         try:
# -> 1037             return self._cython_agg_general('mean', **kwargs)
#    1038         except GroupByError:
#    1039             raise
#
# C:\Users\bilal\Anaconda3\lib\site-packages\pandas\core\groupby.py in _cython_agg_general(self, how, alt, numeric_only)
#    3352     def _cython_agg_general(self, how, alt=None, numeric_only=True):
#    3353         new_items, new_blocks = self._cython_agg_blocks(
# -> 3354             how, alt=alt, numeric_only=numeric_only)
#    3355         return self._wrap_agged_blocks(new_items, new_blocks)
# ...

# %%
set['JobTitle'].nunique()
# Out:
# 2159

# %%
set['JobTitle'].value_counts().head(5)
# Out:
# Transit Operator                7036
# Special Nurse                   4389
# Registered Nurse                3736
# Public Svc Aide-Public Works    2518
# Police Officer 3                2421
# Name: JobTitle, dtype: int64

# %%
set['Year']==2011.value_counts().head(4)
# Out:
#   File "<ipython-input-80-031fbc26d94f>", line 1
#     set['Year']==2011.value_counts().head(4)
#                                  ^
# SyntaxError: invalid syntax

# %%
set[set['Year']=='2014']
# Out:
#             Id            EmployeeName                        JobTitle  \
# 110531  110532             David Shinn                  Deputy Chief 3
# 110532  110533              Amy P Hart               Asst Med Examiner
# 110533  110534    William J Coaker Jr.        Chief Investment Officer
# 110534  110535          Gregory P Suhr                 Chief of Police
# 110535  110536    Joanne M Hayes-White          Chief, Fire Department
# 110536  110537         Ellen G Moffatt               Asst Med Examiner
# 110537  110538           John L Martin                     Dept Head V
# 110538  110539       Harlan L Kelly-Jr     Executive Contract Employee
# 110539  110540              Samson Lai  Battalion Chief, Fire Suppress
# 110540  110541        David L Franklin    Asst Chf of Dept (Fire Dept)
# 110541  110542        Edward D Reiskin      Gen Mgr, Public Trnsp Dept
# 110542  110543             Yifang Qian     Senior Physician Specialist
# ...

# %%
set[set['Year']==2013]['JobTitle']
# Out:
# Series([], Name: JobTitle, dtype: object)

# %%
def chiefstring(title):
    if 'chief' in title.lower().split():
        return True
    else:
        return False

# %%
chiefstring('Chief General Manger')
# Out:
# True

# %%
set[['JobTitle','title_len']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-119-f2448853f03b> in <module>()
# ----> 1 set[['JobTitle','title_len']]
#
# C:\Users\bilal\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    1956         if isinstance(key, (Series, np.ndarray, Index, list)):
#    1957             # either boolean or fancy integer index
# -> 1958             return self._getitem_array(key)
#    1959         elif isinstance(key, DataFrame):
#    1960             return self._getitem_frame(key)
#
# C:\Users\bilal\Anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_array(self, key)
#    2000             return self.take(indexer, axis=0, convert=False)
#    2001         else:
# -> 2002             indexer = self.loc._convert_to_indexer(key, axis=1)
#    2003             return self.take(indexer, axis=1, convert=True)
#    2004
#
# ...

# %%
set['title_len']=set['JobTitle'].apply(len)

# %%
set[['JobTitle','title_len']]
# Out:
#                                                 JobTitle  title_len
# 0         GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY         46
# 1                        CAPTAIN III (POLICE DEPARTMENT)         31
# 2                        CAPTAIN III (POLICE DEPARTMENT)         31
# 3                   WIRE ROPE CABLE MAINTENANCE MECHANIC         36
# 4           DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)         44
# 5                              ASSISTANT DEPUTY CHIEF II         25
# 6                     BATTALION CHIEF, (FIRE DEPARTMENT)         34
# 7                         DEPUTY DIRECTOR OF INVESTMENTS         30
# 8                     BATTALION CHIEF, (FIRE DEPARTMENT)         34
# 9                 CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)         38
# 10      ASSISTANT CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)         48
# 11                       CAPTAIN III (POLICE DEPARTMENT)         31
# 12                           EXECUTIVE CONTRACT EMPLOYEE         27
# ...

# %%
set[['EmployeeName','title_len']].corr()
# Out:
#            title_len
# title_len        1.0

# %%
set[['JobTitle','title_len']].corr()
# Out:
#            title_len
# title_len        1.0
